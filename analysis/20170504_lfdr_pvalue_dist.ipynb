# %% [markdown]
# # Plots of p-value and LFDR for all genes in simulated dataset

# %%
from simulation import *
from power_typeIerror import *
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()
readRDS = robjects.r['readRDS']
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_pvalue_all_genes(input_data):
    '''get p values of fisher's exact test of all genes from pkl input'''
    dat = load_data(input_data)
    sample_genes = get_gene_table(dat)
    pvalue_all_genes = test_contingency_table(sample_genes)
    return pvalue_all_genes

# %%
pvalue = get_pvalue_all_genes("data/del_sim_shape9_scale1_p0.01_N4000_M100_12.data.pkl")

# %%
print (len([x for x in pvalue["p_value"] if x < 0.05]))
# There are 564 genes whose fisher exact pvalue less than 0.05
# Out:
# 943

# %%
plt.scatter(range(len(pvalue["p_value"])), sorted(pvalue["p_value"]))
plt.ylabel("pvalue of fisher exact test")
# plt.show()
plt.savefig("pvalue_dist.png")
plt.close()

# %%
def get_lfdr_all_genes(rds_data):
    df = readRDS(rds_data)
    df = pandas2ri.ri2py(df)
    pip_rds = df[20]
    # pip_genes = list(pip_rds.names[0])
    pip_list = np.array(np.matrix(pip_rds)).reshape(-1,).tolist()
    lfdr = [(1-x) for x in pip_list]
    return lfdr

# %%
lfdr = get_lfdr_all_genes("data/del_sim_shape9_scale1_p0.01_N4000_M100_12.data.feather.RDS")

# %%
plt.scatter(range(len(lfdr)), sorted(lfdr))
plt.ylabel("local false discovery rate")
# plt.show()
plt.savefig("lfdr_dist.png")
plt.close()

# %%
plt.hist(pvalue["p_value"])
# plt.show()
plt.savefig("pvalue_hist")
plt.close()

# %%
plt.hist(lfdr)
plt.savefig("lfdr_hist")
plt.close()

# %%
print (pvalue)
# Out:
# {'p_value': [9.472912750092311e-07, 4.6104559562517035e-06, 1.4988277261358386e-06, 2.017802319619887e-06, 3.554077949239031e-06, 3.554077949239031e-06, 5.8708637840058495e-06, 0.002001864071158736, 0.1664784766641843, 1.6645556763521426e-05, 6.688868637506512e-06, 8.150273713686261e-05, 0.0018116533340321818, 0.0018116533340321818, 1.2516177017550859e-05, 1.2516177017550859e-05, 1.2516177017550859e-05, 0.0005789312288214949, 0.0005789312288214949, 1.0, 0.0005789312288214949, 0.006081394450393239, 1.1241637689558398e-05, 0.0009690676649377224, 0.00023223266867669856, 1.9240330224007283e-05, 0.38159627751299857, 0.12197562171069645, 0.00040212441207034146, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 3.362695033944339e-05, 0.00040212441207034146, 6.014009921600868e-05, 6.014009921600868e-05, 6.014009921600868e-05, 6.014009921600868e-05, 6.014009921600868e-05, 6.014009921600868e-05, 6.014009921600868e-05, 6.014009