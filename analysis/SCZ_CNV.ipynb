# %% [markdown]
# ### Use data from the paper of ["Contribution of CNV to Schizophrenia"](http://www.nature.com/ng/journal/v49/n1/full/ng.3725.html) for analysis

# %%
import pandas as pd

# %%
scz_data = pd.read_table("~/Downloads/SCZ_CNV/PGC_41K_QC_del_minimum8cnv.gene.results", sep="\s+", header = 0, 
                         usecols = (0,1,2,3,4,5,6,7,10), names = ["CHR", "BP_start_hg19", "AFF", "UNAFF", "AFF_T", 
                                                                  "UNAFF_T", "glm_beta", "glm_pval", "BN_FDR"])

# %%
scz_data
# Out:
#           CHR BP_start_hg19          AFF  UNAFF  AFF_T  UNAFF_T  glm_beta  \
# 0      ZDHHC8            22   18499364.0     58      0    17506     16751
# 1       ARVCF            22   18337402.0     57      0    17506     16751
# 2       DGCR8            22   18447755.0     57      0    17506     16751
# 3      RANBP1            22   18485024.0     57      0    17506     16751
# 4      TRMT2A            22   18479389.0     57      0    17506     16751
# 5       RTN4R            22   18608938.0     57      0    17506     16751
# 6      CLTCL1            22   17546987.0     56      0    17506     16751
# 7    C22orf29            22   18213661.0     56      0    17506     16751
# 8       GNB1L            22   18155934.0     56      0    17506     16751
# 9       SEPT5            22   18081987.0     56      0    17506     16751
# 10       TBX1            22   18124226.0     56      0    17506     16751
# 11   C22orf39            22   17808410.0     55      0    17506     16751
# ...
