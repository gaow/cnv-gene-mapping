# %% [markdown]
# # DAP on simulation results

# %%
import numpy as np
import pandas as pd
from pprint import pprint
# from pandasql import sqldf
from scipy import stats
# import pickle
import feather
from collections import Counter
from datetime import datetime
from utils import run_dap, load_data
import os
filename = 'data/calcium_pathway_4000_shape_25.data.blocks.pkl'
fileout = "data/calcium_pathway_4000_shape_25.data"
print(fileout)
# Out:
# data/calcium_pathway_4000_shape_25.data

# %% [markdown]
# ## Data transform: $y \in \{0,1\}$ to $y \in \{0,t\}$

# %%
data = load_data(filename)
# the lifetime prevalence of schizophrenia is 4.0/1000, not 1%, but we first set it as 0.01
# according to https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1140960/
# relative risk is normally between 2 and 10
RR = 2.5
prevalence = data['debug']['args']['prevalence']
t = stats.norm(0,1).ppf(1-prevalence)
# effect size of beta is z_mu, prior
z_mu = t - stats.norm(0,1).ppf(1-RR*prevalence)
print (t, z_mu)
# Out:
# 2.57582930355 0.334426575944

# %%
# create prior file
cal_pthwy_genes = pd.read_table("../data/calciumgeneset.txt", skiprows = 2, header = None, names = ["gene_name"])
ref_genes = pd.read_table("../data/refGene.txt.gz", compression="gzip", sep="\t", header = None, 
                          usecols=(2,12), names=["chrom", "gene_name"]).drop_duplicates(subset=("gene_name"))
calpath_gene_pos = pd.merge(ref_genes, cal_pthwy_genes, how="inner", on=["gene_name"])
diff = set(cal_pthwy_genes["gene_name"].tolist()) - set(calpath_gene_pos["gene_name"].tolist())
# add the two missing genes and their chromosome in the dataframe
calpath_gene_pos.loc[calpath_gene_pos.shape[0]] = ["chr2", list(diff)[0]]
calpath_gene_pos.loc[calpath_gene_pos.shape[0]] = ["chr15", list(diff)[1]]

# %%
calpath_gene_pos["chr.gene"] = calpath_gene_pos.apply(lambda row: "{}.{}".format(row["chrom"], row["gene_name"]), 
                                                      axis=1)
calpath_gene_pos["prior.pr"] = calpath_gene_pos.apply(lambda row: np.random.uniform(0, z_mu), axis=1)

# %%
beta = z_mu
y_tran = t

# %% [markdown]
# ## Run DAP

# %%
dap_method = 'dap-g'
multiplier = 10
fileout = fileout + '_multiplier{}.{}'.format(multiplier, dap_method)
# clean it up, very important!
if os.path.isfile(fileout):
    os.remove(fileout)
os.system('rm -f /tmp/F*{dat,prior,grid}')
for idx, df in enumerate(data['data']):
    df["phenotype"] = df.apply(lambda row: y_tran if row["phenotype"]==1.0 else 0, axis=1)
    times = run_dap(df, fileout, cal_pthwy_genes, ref_genes, grid = [(0, beta)], 
                    multiplier = multiplier, ncpu = 4, dry_run = False, dap_method = dap_method)
    print('Job {2}/{3}, elapsed {0:.2f}s prepare & {1:.2f}s DAP'.\
          format(times[1] - times[0], times[2] - times[1], idx + 1, len(data['data'])))
# Out:
# Job 1/1848, elapsed 2.32s prepare & 1382.34s DAP
# Job 2/1848, elapsed 0.09s prepare & 1.35s DAP
# Job 3/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 4/1848, elapsed 0.81s prepare & 1315.79s DAP
# Job 5/1848, elapsed 1.43s prepare & 620.19s DAP
# Job 6/1848, elapsed 0.33s prepare & 2.46s DAP
# Job 7/1848, elapsed 0.15s prepare & 1.26s DAP
# Job 8/1848, elapsed 2.83s prepare & 201.48s DAP
# Job 9/1848, elapsed 0.51s prepare & 91.10s DAP
# Job 10/1848, elapsed 0.41s prepare & 17.29s DAP
# Job 11/1848, elapsed 0.95s prepare & 1385.32s DAP
# Job 12/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 13/1848, elapsed 0.84s prepare & 787.88s DAP
# Job 14/1848, elapsed 0.35s prepare & 4.58s DAP
# Job 15/1848, elapsed 0.17s prepare & 2.07s DAP
# Job 16/1848, elapsed 0.34s prepare & 4.49s DAP
# Job 17/1848, elapsed 0.32s prepare & 4.26s DAP
# Job 18/1848, elapsed 0.21s prepare & 2.63s DAP
# Job 19/1848, elapsed 1.51s prepare & 3869.17s DAP
# Job 20/1848, elapsed 0.45s prepare & 3.42s DAP
# Job 21/1848, elapsed 0.11s prepare & 1.54s DAP
# Job 22/1848, elapsed 0.82s prepare & 40.18s DAP
# Job 23/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 24/1848, elapsed 0.64s prepare & 118.72s DAP
# Job 25/1848, elapsed 0.30s prepare & 3.75s DAP
# Job 26/1848, elapsed 0.08s prepare & 1.21s DAP
# Job 27/1848, elapsed 0.27s prepare & 3.63s DAP
# Job 28/1848, elapsed 0.15s prepare & 2.02s DAP
# Job 29/1848, elapsed 0.62s prepare & 105.33s DAP
# Job 30/1848, elapsed 0.18s prepare & 2.28s DAP
# Job 31/1848, elapsed 1.59s prepare & 430.84s DAP
# Job 32/1848, elapsed 0.57s prepare & 20.13s DAP
# Job 33/1848, elapsed 0.60s prepare & 17.39s DAP
# Job 34/1848, elapsed 0.61s prepare & 4.22s DAP
# Job 35/1848, elapsed 0.06s prepare & 0.71s DAP
# Job 36/1848, elapsed 0.06s prepare & 0.70s DAP
# Job 37/1848, elapsed 1.39s prepare & 582.42s DAP
# Job 38/1848, elapsed 0.06s prepare & 0.72s DAP
# Job 39/1848, elapsed 0.20s prepare & 2.99s DAP
# Job 40/1848, elapsed 0.19s prepare & 2.34s DAP
# Job 41/1848, elapsed 0.03s prepare & 0.56s DAP
# Job 42/1848, elapsed 2.20s prepare & 3826.40s DAP
# Job 43/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 44/1848, elapsed 0.23s prepare & 1.81s DAP
# Job 45/1848, elapsed 0.06s prepare & 0.68s DAP
# Job 46/1848, elapsed 0.45s prepare & 3.43s DAP
# Job 47/1848, elapsed 0.16s prepare & 2.15s DAP
# Job 48/1848, elapsed 0.11s prepare & 1.67s DAP
# Job 49/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 50/1848, elapsed 0.16s prepare & 2.10s DAP
# Job 51/1848, elapsed 0.29s prepare & 6.20s DAP
# Job 52/1848, elapsed 0.53s prepare & 3.87s DAP
# Job 53/1848, elapsed 1.78s prepare & 2785.42s DAP
# Job 54/1848, elapsed 0.82s prepare & 38.90s DAP
# Job 55/1848, elapsed 0.93s prepare & 634.35s DAP
# Job 56/1848, elapsed 0.10s prepare & 1.49s DAP
# Job 57/1848, elapsed 0.12s prepare & 1.87s DAP
# Job 58/1848, elapsed 0.07s prepare & 1.17s DAP
# Job 59/1848, elapsed 0.11s prepare & 1.64s DAP
# Job 60/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 61/1848, elapsed 0.25s prepare & 3.10s DAP
# Job 62/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 63/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 64/1848, elapsed 0.11s prepare & 1.51s DAP
# Job 65/1848, elapsed 0.06s prepare & 1.01s DAP
# Job 66/1848, elapsed 0.56s prepare & 76.05s DAP
# Job 67/1848, elapsed 0.31s prepare & 4.00s DAP
# Job 68/1848, elapsed 0.31s prepare & 3.93s DAP
# Job 69/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 70/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 71/1848, elapsed 0.34s prepare & 4.34s DAP
# Job 72/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 73/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 74/1848, elapsed 0.10s prepare & 1.49s DAP
# Job 75/1848, elapsed 0.28s prepare & 3.60s DAP
# Job 76/1848, elapsed 0.29s prepare & 3.85s DAP
# Job 77/1848, elapsed 0.21s prepare & 2.79s DAP
# Job 78/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 79/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 80/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 81/1848, elapsed 0.18s prepare & 2.37s DAP
# Job 82/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 83/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 84/1848, elapsed 0.07s prepare & 1.02s DAP
# Job 85/1848, elapsed 0.22s prepare & 8.91s DAP
# Job 86/1848, elapsed 0.36s prepare & 10.60s DAP
# Job 87/1848, elapsed 0.06s prepare & 0.69s DAP
# Job 88/1848, elapsed 0.49s prepare & 3.60s DAP
# Job 89/1848, elapsed 0.13s prepare & 1.19s DAP
# Job 90/1848, elapsed 0.14s prepare & 1.16s DAP
# Job 91/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 92/1848, elapsed 0.27s prepare & 3.57s DAP
# Job 93/1848, elapsed 0.09s prepare & 1.36s DAP
# Job 94/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 95/1848, elapsed 0.07s prepare & 1.18s DAP
# Job 96/1848, elapsed 0.09s prepare & 1.36s DAP
# Job 97/1848, elapsed 0.03s prepare & 0.57s DAP
# Job 98/1848, elapsed 0.09s prepare & 0.88s DAP
# Job 99/1848, elapsed 0.09s prepare & 0.86s DAP
# Job 100/1848, elapsed 0.06s prepare & 0.70s DAP
# Job 101/1848, elapsed 0.35s prepare & 2.49s DAP
# Job 102/1848, elapsed 0.12s prepare & 1.04s DAP
# Job 103/1848, elapsed 0.06s prepare & 0.66s DAP
# Job 104/1848, elapsed 0.09s prepare & 1.38s DAP
# Job 105/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 106/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 107/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 108/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 109/1848, elapsed 0.11s prepare & 1.54s DAP
# Job 110/1848, elapsed 0.11s prepare & 1.73s DAP
# Job 111/1848, elapsed 0.21s prepare & 2.78s DAP
# Job 112/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 113/1848, elapsed 0.05s prepare & 0.89s DAP
# Job 114/1848, elapsed 0.05s prepare & 0.89s DAP
# Job 115/1848, elapsed 0.05s prepare & 0.85s DAP
# Job 116/1848, elapsed 0.08s prepare & 1.22s DAP
# Job 117/1848, elapsed 0.03s prepare & 0.71s DAP
# Job 118/1848, elapsed 0.18s prepare & 2.20s DAP
# Job 119/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 120/1848, elapsed 0.05s prepare & 0.89s DAP
# Job 121/1848, elapsed 0.07s prepare & 1.15s DAP
# Job 122/1848, elapsed 0.09s prepare & 1.32s DAP
# Job 123/1848, elapsed 0.09s prepare & 1.38s DAP
# Job 124/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 125/1848, elapsed 0.10s prepare & 1.48s DAP
# Job 126/1848, elapsed 0.17s prepare & 2.30s DAP
# Job 127/1848, elapsed 0.07s prepare & 1.16s DAP
# Job 128/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 129/1848, elapsed 0.13s prepare & 1.84s DAP
# Job 130/1848, elapsed 0.15s prepare & 1.97s DAP
# Job 131/1848, elapsed 0.05s prepare & 0.88s DAP
# Job 132/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 133/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 134/1848, elapsed 0.08s prepare & 1.18s DAP
# Job 135/1848, elapsed 0.07s prepare & 1.20s DAP
# Job 136/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 137/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 138/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 139/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 140/1848, elapsed 0.05s prepare & 0.95s DAP
# Job 141/1848, elapsed 0.03s prepare & 0.56s DAP
# Job 142/1848, elapsed 0.06s prepare & 0.68s DAP
# Job 143/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 144/1848, elapsed 0.07s prepare & 0.99s DAP
# Job 145/1848, elapsed 0.05s prepare & 0.85s DAP
# Job 146/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 147/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 148/1848, elapsed 0.06s prepare & 1.14s DAP
# Job 149/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 150/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 151/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 152/1848, elapsed 0.07s prepare & 1.20s DAP
# Job 153/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 154/1848, elapsed 0.06s prepare & 1.00s DAP
# Job 155/1848, elapsed 1.04s prepare & 3614.48s DAP
# Job 156/1848, elapsed 0.27s prepare & 11.12s DAP
# Job 157/1848, elapsed 1.49s prepare & 3932.56s DAP
# Job 158/1848, elapsed 1.49s prepare & 761.54s DAP
# Job 159/1848, elapsed 0.10s prepare & 1.53s DAP
# Job 160/1848, elapsed 0.93s prepare & 1033.75s DAP
# Job 161/1848, elapsed 0.43s prepare & 27.95s DAP
# Job 162/1848, elapsed 0.10s prepare & 1.48s DAP
# Job 163/1848, elapsed 1.54s prepare & 2852.16s DAP
# Job 164/1848, elapsed 0.62s prepare & 324.99s DAP
# Job 165/1848, elapsed 1.27s prepare & 154.14s DAP
# Job 166/1848, elapsed 0.03s prepare & 0.65s DAP
# Job 167/1848, elapsed 0.28s prepare & 3.52s DAP
# Job 168/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 169/1848, elapsed 0.26s prepare & 3.41s DAP
# Job 170/1848, elapsed 0.55s prepare & 80.33s DAP
# Job 171/1848, elapsed 0.33s prepare & 4.25s DAP
# Job 172/1848, elapsed 0.40s prepare & 11.32s DAP
# Job 173/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 174/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 175/1848, elapsed 0.04s prepare & 0.82s DAP
# Job 176/1848, elapsed 0.15s prepare & 2.17s DAP
# Job 177/1848, elapsed 0.16s prepare & 2.19s DAP
# Job 178/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 179/1848, elapsed 0.13s prepare & 1.82s DAP
# Job 180/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 181/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 182/1848, elapsed 0.27s prepare & 3.33s DAP
# Job 183/1848, elapsed 0.09s prepare & 1.36s DAP
# Job 184/1848, elapsed 0.23s prepare & 2.92s DAP
# Job 185/1848, elapsed 0.28s prepare & 3.67s DAP
# Job 186/1848, elapsed 0.10s prepare & 1.51s DAP
# Job 187/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 188/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 189/1848, elapsed 0.21s prepare & 2.87s DAP
# Job 190/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 191/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 192/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 193/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 194/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 195/1848, elapsed 0.06s prepare & 1.01s DAP
# Job 196/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 197/1848, elapsed 0.10s prepare & 1.45s DAP
# Job 198/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 199/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 200/1848, elapsed 0.09s prepare & 1.30s DAP
# Job 201/1848, elapsed 0.06s prepare & 0.99s DAP
# Job 202/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 203/1848, elapsed 0.07s prepare & 1.14s DAP
# Job 204/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 205/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 206/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 207/1848, elapsed 0.05s prepare & 0.83s DAP
# Job 208/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 209/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 210/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 211/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 212/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 213/1848, elapsed 0.13s prepare & 1.82s DAP
# Job 214/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 215/1848, elapsed 0.04s prepare & 0.82s DAP
# Job 216/1848, elapsed 0.10s prepare & 1.47s DAP
# Job 217/1848, elapsed 0.06s prepare & 0.98s DAP
# Job 218/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 219/1848, elapsed 0.07s prepare & 1.14s DAP
# Job 220/1848, elapsed 0.07s prepare & 1.17s DAP
# Job 221/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 222/1848, elapsed 0.08s prepare & 1.32s DAP
# Job 223/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 224/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 225/1848, elapsed 0.15s prepare & 2.15s DAP
# Job 226/1848, elapsed 0.07s prepare & 1.16s DAP
# Job 227/1848, elapsed 0.04s prepare & 0.82s DAP
# Job 228/1848, elapsed 0.07s prepare & 1.14s DAP
# Job 229/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 230/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 231/1848, elapsed 0.05s prepare & 0.81s DAP
# Job 232/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 233/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 234/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 235/1848, elapsed 0.04s prepare & 0.83s DAP
# Job 236/1848, elapsed 0.10s prepare & 1.47s DAP
# Job 237/1848, elapsed 0.05s prepare & 0.83s DAP
# Job 238/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 239/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 240/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 241/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 242/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 243/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 244/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 245/1848, elapsed 0.07s prepare & 1.15s DAP
# Job 246/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 247/1848, elapsed 0.03s prepare & 0.65s DAP
# Job 248/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 249/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 250/1848, elapsed 0.04s prepare & 0.81s DAP
# Job 251/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 252/1848, elapsed 0.30s prepare & 12.72s DAP
# Job 253/1848, elapsed 0.39s prepare & 18.11s DAP
# Job 254/1848, elapsed 0.12s prepare & 1.84s DAP
# Job 255/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 256/1848, elapsed 0.24s prepare & 3.17s DAP
# Job 257/1848, elapsed 1.09s prepare & 3820.95s DAP
# Job 258/1848, elapsed 0.08s prepare & 1.32s DAP
# Job 259/1848, elapsed 0.04s prepare & 0.83s DAP
# Job 260/1848, elapsed 4.05s prepare & 243.54s DAP
# Job 261/1848, elapsed 0.03s prepare & 0.52s DAP
# Job 262/1848, elapsed 1.20s prepare & 3625.15s DAP
# Job 263/1848, elapsed 0.12s prepare & 1.68s DAP
# Job 264/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 265/1848, elapsed 0.20s prepare & 2.63s DAP
# Job 266/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 267/1848, elapsed 0.07s prepare & 1.18s DAP
# Job 268/1848, elapsed 0.40s prepare & 23.36s DAP
# Job 269/1848, elapsed 0.37s prepare & 10.70s DAP
# Job 270/1848, elapsed 0.39s prepare & 28.78s DAP
# Job 271/1848, elapsed 0.28s prepare & 3.65s DAP
# Job 272/1848, elapsed 0.20s prepare & 2.64s DAP
# Job 273/1848, elapsed 0.11s prepare & 1.65s DAP
# Job 274/1848, elapsed 0.37s prepare & 11.12s DAP
# Job 275/1848, elapsed 0.07s prepare & 1.16s DAP
# Job 276/1848, elapsed 0.10s prepare & 1.49s DAP
# Job 277/1848, elapsed 0.30s prepare & 3.80s DAP
# Job 278/1848, elapsed 0.05s prepare & 0.85s DAP
# Job 279/1848, elapsed 0.25s prepare & 3.35s DAP
# Job 280/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 281/1848, elapsed 0.50s prepare & 55.44s DAP
# Job 282/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 283/1848, elapsed 0.30s prepare & 3.84s DAP
# Job 284/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 285/1848, elapsed 0.04s prepare & 0.81s DAP
# Job 286/1848, elapsed 0.10s prepare & 1.47s DAP
# Job 287/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 288/1848, elapsed 1.40s prepare & 3621.68s DAP
# Job 289/1848, elapsed 0.43s prepare & 28.91s DAP
# Job 290/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 291/1848, elapsed 0.23s prepare & 4.32s DAP
# Job 292/1848, elapsed 0.08s prepare & 1.23s DAP
# Job 293/1848, elapsed 0.25s prepare & 3.29s DAP
# Job 294/1848, elapsed 0.06s prepare & 1.00s DAP
# Job 295/1848, elapsed 0.42s prepare & 30.41s DAP
# Job 296/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 297/1848, elapsed 0.58s prepare & 96.00s DAP
# Job 298/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 299/1848, elapsed 0.13s prepare & 1.83s DAP
# Job 300/1848, elapsed 0.12s prepare & 1.64s DAP
# Job 301/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 302/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 303/1848, elapsed 0.25s prepare & 3.34s DAP
# Job 304/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 305/1848, elapsed 0.06s prepare & 1.00s DAP
# Job 306/1848, elapsed 0.07s prepare & 1.16s DAP
# Job 307/1848, elapsed 0.14s prepare & 1.99s DAP
# Job 308/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 309/1848, elapsed 0.09s prepare & 1.33s DAP
# Job 310/1848, elapsed 0.11s prepare & 1.65s DAP
# Job 311/1848, elapsed 0.91s prepare & 2249.40s DAP
# Job 312/1848, elapsed 0.06s prepare & 0.70s DAP
# Job 313/1848, elapsed 0.04s prepare & 0.67s DAP
# Job 314/1848, elapsed 0.07s prepare & 1.15s DAP
# Job 315/1848, elapsed 0.10s prepare & 1.47s DAP
# Job 316/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 317/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 318/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 319/1848, elapsed 0.08s prepare & 1.21s DAP
# Job 320/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 321/1848, elapsed 0.08s prepare & 1.16s DAP
# Job 322/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 323/1848, elapsed 0.10s prepare & 1.32s DAP
# Job 324/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 325/1848, elapsed 0.08s prepare & 1.21s DAP
# Job 326/1848, elapsed 0.05s prepare & 0.85s DAP
# Job 327/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 328/1848, elapsed 0.10s prepare & 1.54s DAP
# Job 329/1848, elapsed 0.06s prepare & 0.98s DAP
# Job 330/1848, elapsed 0.02s prepare & 0.66s DAP
# Job 331/1848, elapsed 0.11s prepare & 1.02s DAP
# Job 332/1848, elapsed 0.03s prepare & 0.52s DAP
# Job 333/1848, elapsed 0.06s prepare & 1.04s DAP
# Job 334/1848, elapsed 0.06s prepare & 0.98s DAP
# Job 335/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 336/1848, elapsed 0.03s prepare & 0.77s DAP
# Job 337/1848, elapsed 0.05s prepare & 0.85s DAP
# Job 338/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 339/1848, elapsed 0.19s prepare & 2.54s DAP
# Job 340/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 341/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 342/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 343/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 344/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 345/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 346/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 347/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 348/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 349/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 350/1848, elapsed 0.13s prepare & 1.85s DAP
# Job 351/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 352/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 353/1848, elapsed 0.05s prepare & 0.68s DAP
# Job 354/1848, elapsed 0.07s prepare & 1.15s DAP
# Job 355/1848, elapsed 0.05s prepare & 0.85s DAP
# Job 356/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 357/1848, elapsed 0.15s prepare & 2.03s DAP
# Job 358/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 359/1848, elapsed 0.06s prepare & 1.01s DAP
# Job 360/1848, elapsed 0.04s prepare & 0.67s DAP
# Job 361/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 362/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 363/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 364/1848, elapsed 1.01s prepare & 2922.66s DAP
# Job 365/1848, elapsed 0.72s prepare & 427.40s DAP
# Job 366/1848, elapsed 0.20s prepare & 1.69s DAP
# Job 367/1848, elapsed 0.40s prepare & 3.07s DAP
# Job 368/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 369/1848, elapsed 0.12s prepare & 1.73s DAP
# Job 370/1848, elapsed 0.29s prepare & 18.88s DAP
# Job 371/1848, elapsed 0.85s prepare & 1388.36s DAP
# Job 372/1848, elapsed 1.03s prepare & 59.14s DAP
# Job 373/1848, elapsed 2.08s prepare & 908.54s DAP
# Job 374/1848, elapsed 0.12s prepare & 1.69s DAP
# Job 375/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 376/1848, elapsed 0.33s prepare & 12.98s DAP
# Job 377/1848, elapsed 0.22s prepare & 16.39s DAP
# Job 378/1848, elapsed 0.74s prepare & 124.92s DAP
# Job 379/1848, elapsed 0.36s prepare & 2.75s DAP
# Job 380/1848, elapsed 0.08s prepare & 1.20s DAP
# Job 381/1848, elapsed 0.06s prepare & 1.07s DAP
# Job 382/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 383/1848, elapsed 0.45s prepare & 51.27s DAP
# Job 384/1848, elapsed 0.06s prepare & 1.00s DAP
# Job 385/1848, elapsed 0.08s prepare & 1.16s DAP
# Job 386/1848, elapsed 1.72s prepare & 1945.58s DAP
# Job 387/1848, elapsed 3.74s prepare & 3855.92s DAP
# Job 388/1848, elapsed 0.15s prepare & 1.37s DAP
# Job 389/1848, elapsed 0.33s prepare & 35.48s DAP
# Job 390/1848, elapsed 0.08s prepare & 1.29s DAP
# Job 391/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 392/1848, elapsed 0.15s prepare & 2.17s DAP
# Job 393/1848, elapsed 0.91s prepare & 1200.87s DAP
# Job 394/1848, elapsed 0.15s prepare & 2.15s DAP
# Job 395/1848, elapsed 0.20s prepare & 2.61s DAP
# Job 396/1848, elapsed 0.42s prepare & 3.89s DAP
# Job 397/1848, elapsed 0.09s prepare & 0.84s DAP
# Job 398/1848, elapsed 0.11s prepare & 1.06s DAP
# Job 399/1848, elapsed 0.69s prepare & 11.51s DAP
# Job 400/1848, elapsed 0.12s prepare & 1.04s DAP
# Job 401/1848, elapsed 0.17s prepare & 1.36s DAP
# Job 402/1848, elapsed 0.17s prepare & 2.17s DAP
# Job 403/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 404/1848, elapsed 0.04s prepare & 0.86s DAP
# Job 405/1848, elapsed 0.22s prepare & 2.87s DAP
# Job 406/1848, elapsed 0.11s prepare & 1.52s DAP
# Job 407/1848, elapsed 0.06s prepare & 1.03s DAP
# Job 408/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 409/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 410/1848, elapsed 0.28s prepare & 3.56s DAP
# Job 411/1848, elapsed 0.18s prepare & 2.48s DAP
# Job 412/1848, elapsed 0.05s prepare & 0.87s DAP
# Job 413/1848, elapsed 0.15s prepare & 1.98s DAP
# Job 414/1848, elapsed 0.27s prepare & 6.75s DAP
# Job 415/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 416/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 417/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 418/1848, elapsed 0.09s prepare & 1.32s DAP
# Job 419/1848, elapsed 0.04s prepare & 0.86s DAP
# Job 420/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 421/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 422/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 423/1848, elapsed 0.20s prepare & 2.67s DAP
# Job 424/1848, elapsed 0.26s prepare & 3.32s DAP
# Job 425/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 426/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 427/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 428/1848, elapsed 0.14s prepare & 1.21s DAP
# Job 429/1848, elapsed 0.06s prepare & 0.68s DAP
# Job 430/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 431/1848, elapsed 0.19s prepare & 2.52s DAP
# Job 432/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 433/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 434/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 435/1848, elapsed 0.10s prepare & 1.52s DAP
# Job 436/1848, elapsed 0.06s prepare & 0.98s DAP
# Job 437/1848, elapsed 0.06s prepare & 1.00s DAP
# Job 438/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 439/1848, elapsed 0.11s prepare & 1.67s DAP
# Job 440/1848, elapsed 0.15s prepare & 2.12s DAP
# Job 441/1848, elapsed 0.03s prepare & 0.70s DAP
# Job 442/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 443/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 444/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 445/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 446/1848, elapsed 0.08s prepare & 1.37s DAP
# Job 447/1848, elapsed 0.09s prepare & 1.34s DAP
# Job 448/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 449/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 450/1848, elapsed 0.13s prepare & 1.68s DAP
# Job 451/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 452/1848, elapsed 0.32s prepare & 4.02s DAP
# Job 453/1848, elapsed 0.17s prepare & 2.25s DAP
# Job 454/1848, elapsed 0.30s prepare & 4.05s DAP
# Job 455/1848, elapsed 0.63s prepare & 579.71s DAP
# Job 456/1848, elapsed 0.04s prepare & 0.83s DAP
# Job 457/1848, elapsed 0.16s prepare & 2.16s DAP
# Job 458/1848, elapsed 0.14s prepare & 1.97s DAP
# Job 459/1848, elapsed 0.02s prepare & 0.50s DAP
# Job 460/1848, elapsed 0.09s prepare & 1.34s DAP
# Job 461/1848, elapsed 0.11s prepare & 1.66s DAP
# Job 462/1848, elapsed 0.27s prepare & 3.59s DAP
# Job 463/1848, elapsed 0.16s prepare & 2.13s DAP
# Job 464/1848, elapsed 0.10s prepare & 1.49s DAP
# Job 465/1848, elapsed 0.20s prepare & 2.77s DAP
# Job 466/1848, elapsed 0.26s prepare & 3.45s DAP
# Job 467/1848, elapsed 0.39s prepare & 24.12s DAP
# Job 468/1848, elapsed 0.30s prepare & 2.31s DAP
# Job 469/1848, elapsed 0.21s prepare & 1.69s DAP
# Job 470/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 471/1848, elapsed 0.24s prepare & 3.20s DAP
# Job 472/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 473/1848, elapsed 0.50s prepare & 58.18s DAP
# Job 474/1848, elapsed 0.09s prepare & 1.34s DAP
# Job 475/1848, elapsed 0.22s prepare & 3.27s DAP
# Job 476/1848, elapsed 0.03s prepare & 0.70s DAP
# Job 477/1848, elapsed 0.02s prepare & 0.55s DAP
# Job 478/1848, elapsed 0.23s prepare & 3.05s DAP
# Job 479/1848, elapsed 0.21s prepare & 2.86s DAP
# Job 480/1848, elapsed 0.06s prepare & 1.01s DAP
# Job 481/1848, elapsed 0.42s prepare & 21.27s DAP
# Job 482/1848, elapsed 0.07s prepare & 1.16s DAP
# Job 483/1848, elapsed 0.23s prepare & 2.36s DAP
# Job 484/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 485/1848, elapsed 0.06s prepare & 1.03s DAP
# Job 486/1848, elapsed 0.10s prepare & 1.54s DAP
# Job 487/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 488/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 489/1848, elapsed 0.10s prepare & 1.50s DAP
# Job 490/1848, elapsed 0.12s prepare & 1.69s DAP
# Job 491/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 492/1848, elapsed 0.18s prepare & 2.45s DAP
# Job 493/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 494/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 495/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 496/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 497/1848, elapsed 0.05s prepare & 0.88s DAP
# Job 498/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 499/1848, elapsed 0.05s prepare & 0.82s DAP
# Job 500/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 501/1848, elapsed 0.04s prepare & 0.69s DAP
# Job 502/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 503/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 504/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 505/1848, elapsed 0.10s prepare & 1.47s DAP
# Job 506/1848, elapsed 0.09s prepare & 1.36s DAP
# Job 507/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 508/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 509/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 510/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 511/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 512/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 513/1848, elapsed 2.41s prepare & 1302.24s DAP
# Job 514/1848, elapsed 0.45s prepare & 3.70s DAP
# Job 515/1848, elapsed 0.62s prepare & 105.91s DAP
# Job 516/1848, elapsed 1.27s prepare & 1566.14s DAP
# Job 517/1848, elapsed 0.53s prepare & 92.53s DAP
# Job 518/1848, elapsed 0.95s prepare & 1338.93s DAP
# Job 519/1848, elapsed 0.11s prepare & 1.52s DAP
# Job 520/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 521/1848, elapsed 0.03s prepare & 0.72s DAP
# Job 522/1848, elapsed 0.42s prepare & 23.35s DAP
# Job 523/1848, elapsed 0.17s prepare & 2.58s DAP
# Job 524/1848, elapsed 0.11s prepare & 1.58s DAP
# Job 525/1848, elapsed 0.07s prepare & 1.09s DAP
# Job 526/1848, elapsed 0.02s prepare & 0.56s DAP
# Job 527/1848, elapsed 0.20s prepare & 2.66s DAP
# Job 528/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 529/1848, elapsed 0.05s prepare & 0.87s DAP
# Job 530/1848, elapsed 0.21s prepare & 1.79s DAP
# Job 531/1848, elapsed 0.91s prepare & 52.33s DAP
# Job 532/1848, elapsed 0.20s prepare & 1.85s DAP
# Job 533/1848, elapsed 0.11s prepare & 1.52s DAP
# Job 534/1848, elapsed 0.03s prepare & 0.73s DAP
# Job 535/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 536/1848, elapsed 0.07s prepare & 1.06s DAP
# Job 537/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 538/1848, elapsed 0.03s prepare & 0.70s DAP
# Job 539/1848, elapsed 0.02s prepare & 0.56s DAP
# Job 540/1848, elapsed 0.08s prepare & 1.23s DAP
# Job 541/1848, elapsed 0.08s prepare & 1.26s DAP
# Job 542/1848, elapsed 0.09s prepare & 1.38s DAP
# Job 543/1848, elapsed 0.02s prepare & 0.56s DAP
# Job 544/1848, elapsed 0.04s prepare & 0.77s DAP
# Job 545/1848, elapsed 0.02s prepare & 0.59s DAP
# Job 546/1848, elapsed 0.12s prepare & 1.66s DAP
# Job 547/1848, elapsed 0.04s prepare & 0.79s DAP
# Job 548/1848, elapsed 0.06s prepare & 0.96s DAP
# Job 549/1848, elapsed 0.06s prepare & 0.80s DAP
# Job 550/1848, elapsed 0.07s prepare & 0.80s DAP
# Job 551/1848, elapsed 1.38s prepare & 829.41s DAP
# Job 552/1848, elapsed 2.06s prepare & 1674.87s DAP
# Job 553/1848, elapsed 0.47s prepare & 48.24s DAP
# Job 554/1848, elapsed 1.43s prepare & 3903.29s DAP
# Job 555/1848, elapsed 0.59s prepare & 97.12s DAP
# Job 556/1848, elapsed 0.18s prepare & 1.92s DAP
# Job 557/1848, elapsed 0.05s prepare & 1.01s DAP
# Job 558/1848, elapsed 0.09s prepare & 1.41s DAP
# Job 559/1848, elapsed 0.02s prepare & 0.58s DAP
# Job 560/1848, elapsed 0.02s prepare & 0.59s DAP
# Job 561/1848, elapsed 0.51s prepare & 49.10s DAP
# Job 562/1848, elapsed 0.19s prepare & 1.67s DAP
# Job 563/1848, elapsed 0.89s prepare & 50.88s DAP
# Job 564/1848, elapsed 0.16s prepare & 2.08s DAP
# Job 565/1848, elapsed 0.19s prepare & 2.59s DAP
# Job 566/1848, elapsed 0.04s prepare & 0.71s DAP
# Job 567/1848, elapsed 0.03s prepare & 0.71s DAP
# Job 568/1848, elapsed 0.24s prepare & 3.14s DAP
# Job 569/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 570/1848, elapsed 0.83s prepare & 987.24s DAP
# Job 571/1848, elapsed 0.20s prepare & 2.81s DAP
# Job 572/1848, elapsed 0.02s prepare & 0.64s DAP
# Job 573/1848, elapsed 0.05s prepare & 1.00s DAP
# Job 574/1848, elapsed 0.20s prepare & 2.61s DAP
# Job 575/1848, elapsed 0.09s prepare & 1.20s DAP
# Job 576/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 577/1848, elapsed 0.09s prepare & 1.38s DAP
# Job 578/1848, elapsed 0.07s prepare & 1.20s DAP
# Job 579/1848, elapsed 0.14s prepare & 1.75s DAP
# Job 580/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 581/1848, elapsed 0.38s prepare & 5.01s DAP
# Job 582/1848, elapsed 0.08s prepare & 1.38s DAP
# Job 583/1848, elapsed 0.12s prepare & 1.78s DAP
# Job 584/1848, elapsed 0.03s prepare & 0.71s DAP
# Job 585/1848, elapsed 0.04s prepare & 0.69s DAP
# Job 586/1848, elapsed 0.05s prepare & 0.87s DAP
# Job 587/1848, elapsed 0.07s prepare & 1.17s DAP
# Job 588/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 589/1848, elapsed 0.03s prepare & 0.69s DAP
# Job 590/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 591/1848, elapsed 0.05s prepare & 0.88s DAP
# Job 592/1848, elapsed 0.10s prepare & 1.56s DAP
# Job 593/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 594/1848, elapsed 0.07s prepare & 1.20s DAP
# Job 595/1848, elapsed 0.25s prepare & 3.04s DAP
# Job 596/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 597/1848, elapsed 0.18s prepare & 2.58s DAP
# Job 598/1848, elapsed 0.17s prepare & 2.15s DAP
# Job 599/1848, elapsed 0.15s prepare & 2.17s DAP
# Job 600/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 601/1848, elapsed 0.03s prepare & 0.66s DAP
# Job 602/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 603/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 604/1848, elapsed 0.06s prepare & 1.05s DAP
# Job 605/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 606/1848, elapsed 0.04s prepare & 0.84s DAP
# Job 607/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 608/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 609/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 610/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 611/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 612/1848, elapsed 0.11s prepare & 1.50s DAP
# Job 613/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 614/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 615/1848, elapsed 0.16s prepare & 2.19s DAP
# Job 616/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 617/1848, elapsed 0.04s prepare & 0.85s DAP
# Job 618/1848, elapsed 0.06s prepare & 1.02s DAP
# Job 619/1848, elapsed 0.05s prepare & 0.84s DAP
# Job 620/1848, elapsed 0.07s prepare & 1.22s DAP
# Job 621/1848, elapsed 0.53s prepare & 42.80s DAP
# Job 622/1848, elapsed 0.02s prepare & 0.55s DAP
# Job 623/1848, elapsed 1.87s prepare & 370.89s DAP
# Job 624/1848, elapsed 0.14s prepare & 2.05s DAP
# Job 625/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 626/1848, elapsed 0.08s prepare & 1.21s DAP
# Job 627/1848, elapsed 0.35s prepare & 14.36s DAP
# Job 628/1848, elapsed 0.31s prepare & 12.92s DAP
# Job 629/1848, elapsed 1.60s prepare & 3751.67s DAP
# Job 630/1848, elapsed 0.65s prepare & 122.71s DAP
# Job 631/1848, elapsed 0.32s prepare & 22.03s DAP
# Job 632/1848, elapsed 0.67s prepare & 11.22s DAP
# Job 633/1848, elapsed 0.59s prepare & 18.85s DAP
# Job 634/1848, elapsed 0.18s prepare & 2.40s DAP
# Job 635/1848, elapsed 0.12s prepare & 1.72s DAP
# Job 636/1848, elapsed 0.04s prepare & 0.70s DAP
# Job 637/1848, elapsed 0.60s prepare & 91.00s DAP
# Job 638/1848, elapsed 0.03s prepare & 0.53s DAP
# Job 639/1848, elapsed 0.19s prepare & 1.56s DAP
# Job 640/1848, elapsed 0.06s prepare & 0.71s DAP
# Job 641/1848, elapsed 1.52s prepare & 2585.19s DAP
# Job 642/1848, elapsed 0.22s prepare & 2.82s DAP
# Job 643/1848, elapsed 0.07s prepare & 1.19s DAP
# Job 644/1848, elapsed 0.05s prepare & 0.87s DAP
# Job 645/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 646/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 647/1848, elapsed 0.20s prepare & 2.59s DAP
# Job 648/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 649/1848, elapsed 0.23s prepare & 2.97s DAP
# Job 650/1848, elapsed 0.05s prepare & 0.86s DAP
# Job 651/1848, elapsed 0.05s prepare & 1.19s DAP
# Job 652/1848, elapsed 0.02s prepare & 0.55s DAP
# Job 653/1848, elapsed 0.06s prepare & 0.72s DAP
# Job 654/1848, elapsed 0.08s prepare & 1.26s DAP
# Job 655/1848, elapsed 0.34s prepare & 4.22s DAP
# Job 656/1848, elapsed 0.03s prepare & 0.68s DAP
# Job 657/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 658/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 659/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 660/1848, elapsed 0.02s prepare & 0.53s DAP
# Job 661/1848, elapsed 0.27s prepare & 3.20s DAP
# Job 662/1848, elapsed 0.02s prepare & 0.51s DAP
# Job 663/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 664/1848, elapsed 0.03s prepare & 0.71s DAP
# Job 665/1848, elapsed 0.02s prepare & 0.52s DAP
# Job 666/1848, elapsed 0.03s prepare & 0.67s DAP
# Job 667/1848, elapsed 0.12s prepare & 1.66s DAP
# Job 668/1848, elapsed 0.02s prepare & 0.54s DAP
# Job 669/1848, elapsed 0.08s prepare & 1.20s DAP
# Job 670/1848, elapsed 1.02s prepare & 1820.00s DAP
# Job 671/1848, elapsed 0.10s prepare & 1.62s DAP
# Job 672/1848, elapsed 0.88s prepare & 1423.20s DAP
# Job 673/1848, elapsed 2.37s prepare & 3822.07s DAP
# Job 674/1848, elapsed 2.56s prepare & 261.37s DAP
# Job 675/1848, elapsed 0.82s prepare & 801.47s DAP
# Job 676/1848, elapsed 1.45s prepare & 557.27s DAP
# Job 677/1848, elapsed 2.43s prepare & 3827.31s DAP
# Job 678/1848, elapsed 0.16s prepare & 1.85s DAP
# Job 679/1848, elapsed 0.22s prepare & 9.09s DAP

# %%
# dap/dap -d /tmp/F1503014064.6944265.dat -g /tmp/F1503014064.6944265.grid -it 0.05 -prior /tmp/F1503014064.6944265.prior -t 2 > data/calcium_pathway_N4000_shape25_nomask.data.dap

# %%
# calpath_gene_pos.to_csv("test.csv", sep="\t")
print (cal_pthwy_genes["gene_name"].tolist())
# Out:
# ['ADCY1', 'ADCY2', 'ADCY3', 'ADCY4', 'ADCY7', 'ADCY8', 'ADCY9', 'ADORA2A', 'ADORA2B', 'ADRA1A', 'ADRA1B', 'ADRA1D', 'ADRB1', 'ADRB2', 'ADRB3', 'AGTR1', 'ATP2A1', 'ATP2A2', 'ATP2A3', 'ATP2B1', 'ATP2B2', 'ATP2B3', 'ATP2B4', 'AVPR1A', 'AVPR1B', 'BDKRB1', 'BDKRB2', 'BST1', 'CACNA1A', 'CACNA1B', 'CACNA1C', 'CACNA1D', 'CACNA1E', 'CACNA1F', 'CACNA1G', 'CACNA1H', 'CACNA1I', 'CACNA1S', 'CALM1', 'CALM2', 'CALM3', 'CALML3', 'CALML5', 'CALML6', 'CAMK2A', 'CAMK2B', 'CAMK2D', 'CAMK2G', 'CAMK4', 'CCKAR', 'CCKBR', 'CD38', 'CHP', 'CHP2', 'CHRM1', 'CHRM2', 'CHRM3', 'CHRM5', 'CHRNA7', 'CYSLTR1', 'CYSLTR2', 'DRD1', 'DRD5', 'EDNRA', 'EDNRB', 'EGFR', 'ERBB2', 'ERBB3', 'ERBB4', 'F2R', 'GNA11', 'GNA14', 'GNA15', 'GNAL', 'GNAQ', 'GNAS', 'GRIN1', 'GRIN2A', 'GRIN2C', 'GRIN2D', 'GRM1', 'GRM5', 'GRPR', 'HRH1', 'HRH2', 'HTR2A', 'HTR2B', 'HTR2C', 'HTR4', 'HTR5A', 'HTR6', 'HTR7', 'ITPKA', 'ITPKB', 'ITPR1', 'ITPR2', 'ITPR3', 'LHCGR', 'LOC729317', 'LTB4R2', 'MYLK', 'MYLK2', 'MYLK3', 'NOS1', 'NOS2', 'NOS3', 'NTSR1', 'OXTR', 'P2RX1', 'P2RX2', 'P2RX3', 'P2RX4', 'P2RX5', 'P2RX6', 'P2RX7', 'PDE1A', 'PDE1B', 'PDE1C', 'PDGFRA', 'PDGFRB', 'PHKA1', 'PHKA2', 'PHKB', 'PHKG1', 'PHKG2', 'PLCB1', 'PLCB2', 'PLCB3', 'PLCB4', 'PLCD1', 'PLCD3', 'PLCD4', 'PLCE1', 'PLCG1', 'PLCG2', 'PLCZ1', 'PLN', 'PPID', 'PPP3CA', 'PPP3CB', 'PPP3CC', 'PPP3R1', 'PPP3R2', 'PRKACA', 'PRKACB', 'PRKACG', 'PRKCA', 'PRKCB', 'PRKCG', 'PRKX', 'PTAFR', 'PTGER1', 'PTGER3', 'PTGFR', 'PTK2B', 'RYR1', 'RYR2', 'RYR3', 'SLC25A31', 'SLC25A4', 'SLC25A5', 'SLC25A6', 'SLC8A1', 'SLC8A2', 'SLC8A3', 'SPHK1', 'SPHK2', 'TACR1', 'TACR2', 'TACR3', 'TBXA2R', 'TNNC1', 'TNNC2', 'TRHR', 'TRPC1', 'VDAC1', 'VDAC2', 'VDAC3']

# %%
# chrom
# chrom = ["chr{}".format(i) for i in list(range(1,23))+["X"]]
# print ((chrom))

# %%
# [I 15:34:54.151 NotebookApp] Accepting one-time-token-authenticated connection from ::1
# [I 15:34:54.814 NotebookApp] Kernel started: 60079e22-d81d-4f83-a293-c5750b5456a1
# [I 15:36:54.808 NotebookApp] Saving file at /20170726_Dap_on_simulation.ipynb
# [W 15:42:01.170 NotebookApp] WebSocket ping timeout after 92790 ms.
# [I 15:44:57.820 NotebookApp] KernelRestarter: restarting kernel (1/5)
